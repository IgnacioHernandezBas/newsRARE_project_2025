# %%
# !pip install unidecode
# !pip install selenium
# !pip install bs4
# !pip install requests

# %% [markdown]
# # Scraping de los artículos de NewsRare por secciones (Selenium +BS4)

# %%
import pandas as pd
from unidecode import unidecode
import json
import requests

from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from bs4 import BeautifulSoup
import time

# %% [markdown]
# En primer lugar tenemos que poder acceder a cada sección

# %%
# Descargar la página
url = "https://newsrare.es/articulos"
response = requests.get(url)
# Parsear el HTML
soup = BeautifulSoup(response.text, "html.parser")
# Encontrar el bloque de secciones
section_container = soup.find("div", class_="td_block_categories_tags")
# Extraer los enlaces de las secciones
sections = section_container.find_all("a")

sections_urls=[]
nombre_seccion=[]
num_articulos=[]

for content in sections:

    section_url=content["href"]
    name=content.find("span",class_="td-ct-item-name").get_text()
    num=content.find("span",class_="td-ct-item-no").get_text()

    sections_urls.append(section_url)
    nombre_seccion.append(name)
    num_articulos.append(num)

df_secciones=pd.DataFrame({
    "Seccion":nombre_seccion,
    "NºArtículos":num_articulos,
    "URL":sections_urls
})

# %%
df_secciones.head()
# Out:
#                         Seccion NºArtículos  \
# 0                    Actualidad         175
# 1                     Artículos          13
# 2                     Barómetro          16
# 3  Colaboración Público-Privada          24
# 4                        Cursos          14
#
#                                                  URL
# 0            https://newsrare.es/seccion/actualidad/
# 1             https://newsrare.es/seccion/articulos/
# 2             https://newsrare.es/seccion/barometro/
# 3  https://newsrare.es/seccion/entrevistas/colabo...
# 4     https://newsrare.es/seccion/encuentros/cursos/

# %% [markdown]
# Acceder a los artículos de cada sección

# %% [markdown]
# # Obtención de artículos por seccion ( Es necesario usar Selenium para hacer scroll en la página y que cargen todos)

# %%
def obtener_articulos_seccion(url_seccion,filepath):
    # Selenium configuration
    chrome_options = Options()
    chrome_options.add_argument("--headless")  # Correr en headless mode (sin UI)
    chrome_options.add_argument("--disable-gpu")
    chrome_options.add_argument("--no-sandbox")

    # Path al WebDriver
    webdriver_path = "./chromedriver.exe"

    # Iniciar WebDriver
    service = Service(webdriver_path)
    driver = webdriver.Chrome(service=service, options=chrome_options)

    # URL de la página de "Actualidad"
    #url_actualidad = "https://newsrare.es/seccion/actualidad/"
    # Cargar la página
    driver.get(url_seccion)
    category=url_seccion.split("/")[-2]
    filename="noticias_"+category+".json"

    # Espera para asegurar que la página cargue completamente
    time.sleep(3)

    # Realizar scroll para cargar más artículos
    scroll_pause_time = 15  # Tiempo de espera entre desplazamientos
    last_height = driver.execute_script("return document.body.scrollHeight")

    while True:
        # Hacer scroll hasta el fondo de la página
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
        time.sleep(scroll_pause_time)

        # Verificar si el scroll alcanzó el final de la página
        new_height = driver.execute_script("return document.body.scrollHeight")
        if new_height == last_height:
            break
        last_height = new_height

    # Una vez que la página ha cargado completamente, obtener el contenido HTML
    soup = BeautifulSoup(driver.page_source, "html.parser")

    # Buscar los artículos en la categoría 'Actualidad'
    articles = soup.find_all("div", class_="td-module-meta-info")

    # Filtrar los artículos cuya categoría sea 'Actualidad'
    counter=0
    title_set=set()
    noticias_list=[]
    for article in articles:
        category_element = article.find("a", class_="td-post-category")
        category_element_clean = unidecode(category_element.get_text(strip=True).lower()).replace(" ", "-")
        if category_element and category in category_element_clean:
            a_element = article.find("a")
            h3_element = article.find("h3")
            url_article=h3_element.find("a")["href"]
            title=h3_element.get_text(strip=True)
            if title not in title_set: #chequeo de duplicados
                counter+=1
                title_set.add(title)  # Add title to the set
                #print(f"{counter}. {a_element.get_text(strip=True)} | {title} | URL: {url_article}")
                noticias_list.append({
                    "title": title,
                    "url": url_article
                })
    # Cerrar el navegador de Selenium después de terminar
    driver.quit()

    # Creamos json con todas las noticias
    with open(filepath+"/"+filename, "w") as file:
        json.dump(noticias_list, file)
    print("JSON Creado Correctamente: ",filename)

# %%
df_secciones["URL"]
for url in df_secciones["URL"].values:
    print(url)
    filename=url.split("/")[-2]
    print (filename)
# Out:
# https://newsrare.es/seccion/actualidad/
# actualidad
# https://newsrare.es/seccion/articulos/
# articulos
# https://newsrare.es/seccion/barometro/
# barometro
# https://newsrare.es/seccion/entrevistas/colaboracion-publico-privada/
# colaboracion-publico-privada
# https://newsrare.es/seccion/encuentros/cursos/
# cursos
# https://newsrare.es/seccion/encuentros/dialogos/
# dialogos

# %%
for url in df_secciones["URL"]:
    obtener_articulos_seccion(url,"./articles")
# Out:
# JSON Creado Correctamente:  noticias_actualidad.json
# JSON Creado Correctamente:  noticias_articulos.json
# JSON Creado Correctamente:  noticias_barometro.json
# JSON Creado Correctamente:  noticias_colaboracion-publico-privada.json
# JSON Creado Correctamente:  noticias_cursos.json
# JSON Creado Correctamente:  noticias_dialogos.json

# %% [markdown]
# ## Obtención del texto para los artículos para todas las secciones

# %%
import os
import json
import requests
from bs4 import BeautifulSoup

# Path de destino
articles_folder_path = "./articles"

def get_article_text(url):
    """Obtener el texto de un artículo de una URL"""
    try:
        # Realizar la solicitud HTTP para obtener el HTML de la página
        response = requests.get(url)

        if response.status_code == 200:
            # Parsear el HTML con BeautifulSoup
            soup = BeautifulSoup(response.text, 'html.parser')

            # Acceder a la info del artículo
            article_body = soup.find_all(class_="elementor-widget-container")
            article_text = ""
            for section in article_body:
                article_text += section.text + "\n"

            if article_text == "":  # El cuerpo del artículo puede estar en otra clase
                article_body = soup.find_all(class_="td-post-content")
                for section in article_body:
                    article_text += section.text + "\n"

            return article_text.strip()  # Eliminar espacios en blanco extra

        else:
            print(f"Error al acceder a la URL: {url}")
            return None

    except Exception as e:
        print(f"Error al obtener el artículo de {url}: {e}")
        return None

def update_json_files(folder_path):
    """Actualizar los archivos JSON con el texto del artículo"""
    for filename in os.listdir(folder_path):
        if filename.endswith('.json'):
            file_path = os.path.join(folder_path, filename)

            with open(file_path, 'r', encoding='utf-8') as f:
                articles = json.load(f)

            # Actualizar cada entrada con el texto del artículo
            for article in articles:
                url = article.get("url")
                if url:
                    print(f"Procesando artículo: {article['title']}")
                    article_text = get_article_text(url)
                    if article_text:  # Evitar asignar valores vacíos o None
                        article["content"] = article_text

            # Guardar el archivo JSON actualizado (indentación corregida)
            with open(file_path, 'w', encoding='utf-8') as f:
                json.dump(articles, f, ensure_ascii=False, indent=4)
                print(f"Archivo {filename} actualizado.")

# Llamar a la función para actualizar los archivos
update_json_files(articles_folder_path)
# Out:
# Procesando artículo: MEDICAMENTOS
# Procesando artículo: ESPAÑA-OPINIÓN POSITIVA DE LA EMA PARA GARADACIMAB
# Procesando artículo: ESPAÑA-BIOCRYST PRESENTA CUATRO COMUNICACIONES
# Procesando artículo: Nueva ley de la ELA: atención 24 horas, protección a los cuidadores, evaluación de la discapacidad
# Procesando artículo: Publicación del Informe sobre «Optimización de la participación de los pacientes en la evaluación de los medicamentos»
# Procesando artículo: El valor de los medicamentos huérfanos trasciende la salud y calidad de vida del paciente
# Procesando artículo: Los retos de la incorporación de innovación terapéutica en enfermedades raras en España
# Procesando artículo: Desigualdad en Europa: España mejora en el acceso a medicamentos huérfanos, pero enfrenta retrasos significativos en su disponibilidad
# Procesando artículo: PROCESOS REGULATORIOS PARA MEDICAMENTOS CONTRA ENFERMEDADES RARAS EN ESTADOS UNIDOS Y LA UNIÓN EUROPEA. FLEXIBILIDADES Y OPORTUNIDADES DE COLABORACIÓN
# Procesando artículo: Rare Diseases International admitida en las relaciones oficiales con la OMS
# Procesando artículo: MEDICAMENTOS HUÉRFANOS CON FINANCIACIÓN APROBADA POR LA CIPMPS DESDE ENERO HASTA MARZO 2024
# Procesando artículo: MEDICAMENTOS HUÉRFANOS E INDICACIONES APROBADAS POR LA EMA DESDE ENERO HASTA MARZO 2024
# Procesando artículo: BIOCRYST RECIBE LA APROBACIÓN EN ESPAÑA DE ▼ORLADEYO (BEROTRALSTAT)
# Procesando artículo: ULTOMIRIS® (RAVULIZUMAB) DISPONIBLE EN ESPAÑA PARA EL TRATAMIENTO DE ADULTOS CON MIASTENIA GRAVIS GENERALIZADA
# Procesando artículo: UN ESTUDIO EN SHARE4RARE ANALIZA LA ATENCIÓN PSICOLÓGICA QUE RECIBEN LAS PERSONAS CON ENFERMEDADES RARAS EN ESPAÑA
# Procesando artículo: EL NUEVO CATÁLOGO DE BIOMARCADORES PRETENDE RESOLVER LA INEQUIDAD EN EL ACCESO A LAS PRUEBAS GENÉTICAS EN EL SNS
# Procesando artículo: NUEVO TRATAMIENTO PARA ENFERMEDAD RARA DE LAS NEURONAS MOTORAS RECOMENDADO PARA APROBACIÓN
# Procesando artículo: La FDA aprueba el primer tratamiento basado en CRISPR para una segunda enfermedad, la beta talasemia
# Procesando artículo: Pharmacy Forecast en 2024 para facilitar la planificación estratégica del sector
# Procesando artículo: MEDICAMENTOS HUÉRFANOS CON FINANCIACIÓN APROBADA  POR LA CIPMPS DESDE ENERO HASTA DICIEMBRE 2023
# Procesando artículo: MEDICAMENTOS HUÉRFANOS E INDICACIONES APROBADAS POR LA  EMA DESDE ENERO HASTA DICIEMBRE 2023
# Procesando artículo: ENTREGA DE PREMIOS AELMHU
# Procesando artículo: ATLAS DE LA LEUCEMIA MIELOIDE AGUDA EN ESPAÑA
# Procesando artículo: GALICIA LIDERA LA IMPLEMENTACIÓN DEL PRIMER PROCESO ASISTENCIAL INTEGRADO PARA EL DÉFICIT DE ALFA-1 ANTITRIPSINA: AVANZANDO EN UNA ATENCIÓN HOMOGÉNEA Y PRECOZ
# Procesando artículo: ALBIREO, COMPAÑÍA DE IPSEN, LANZA ODEVIXIBAT EN ESPAÑA PARA LA COLESTASIS INTRAHEPÁTICA FAMILIAR PROGRESIVA
# Procesando artículo: ÚNETE A LA CAMPAÑA DEL DÍA MUNDIAL DE LAS ENFERMEDADES RARAS DE EURORDIS
# Procesando artículo: DESTACANDO EL PAPEL VITAL DE LOS PACIENTES CON ENFERMEDADES RARAS EN LA REVISIÓN DE LA LEGISLACIÓN FARMACÉUTICA DE LA UNIÓN EUROPEA
# Procesando artículo: AVANCES EN PRUEBAS GENÉTICAS: NUEVOS RECURSOS PARA EL  DIAGNÓSTICO DE ENFERMEDADES RARAS (EERR)
# Procesando artículo: LANZAMIENTO DE UN PROGRAMA PILOTO PARA AGILIZAR EL ACCESO A TERAPIAS PERSONALIZADAS DESTINADAS A NIÑOS CON ENFERMEDADES RARAS
# Procesando artículo: MEDICAMENTOS HUÉRFANOS CON FINANCIACIÓN APROBADA POR EL CIPMPS DESDE ENERO HASTA AGOSTO 2023
# Procesando artículo: MEDICAMENTOS HUÉRFANOS E INDICACIONES APROBADAS POR LA EMA DESDE ENERO HASTA AGOSTO 2023
# Procesando artículo: KOSELUGO® EN ESPAÑA: TRATAMIENTO DE NEUROFIBROMAS  PLEXIFORMES EN PACIENTES PEDIÁTRICOS CON  NEUROFIBROMATOSIS TIPO 1
# Procesando artículo: LA COMISIÓN INTERMINISTERIAL DE PRECIOS DE LOS MEDICAMENTOS (CIPM) DA LUZ VERDE A LA FINANCIACIÓN DE TAVNEOS® (AVACOPAN)
# Procesando artículo: LA TECNOLOGÍA DE SECUENCIACIÓN DE LECTURA LARGA REVELA NUEVOS DETALLES SOBRE EL SÍNDROME DE BARTTER TIPO 3
# Procesando artículo: LA COMUNIDAD GLOBAL DE ENFERMEDADES RARAS INSTA A LOS ESTADOS MIEMBROS DE LAS NACIONES UNIDAS A CONVERTIR LA COBERTURA UNIVERSAL DE SALUD EN UNA...
# Procesando artículo: AVANCES EN EL APRENDIZAJE AUTOMÁTICO PARA ENFERMEDADES RARAS: NUEVA ESPERANZA PARA LOS PACIENTES
# Procesando artículo: UN ESTUDIO DESTACA LOS DESAFÍOS ENFRENTADOS POR PERSONAS CON ENFERMEDADES RARAS EN QUEBEC
# Procesando artículo: MEDICAMENTOS HUÉRFANOS CON FINANCIACIÓN APROBADA POR EL CIPMPS DESDE ENERO HASTA MARZO 2023
# Procesando artículo: MEDICAMENTOS HUÉRFANOS E INDICACIONES APROBADAS POR LA EMA DESDE ENERO HASTA MARZO 2023
# Procesando artículo: «EDUCAR EN RED»: LA GUÍA QUE FACILITA LA INCLUSIÓN EDUCATIVA DE ESTUDIANTES CON ENFERMEDADES RARAS O SIN DIAGNÓSTICO
# Procesando artículo: SE PRESENTA EL INFORME “NO TODAS LAS PSORIASIS SON IGUALES. EL RETO DE LA PERSONALIZACIÓN»
# Procesando artículo: HEMO. INSTANTES DE UNA VIDA: LA EXPOSICIÓN PROTAGONIZADA POR PACIENTES CON HEMOFILIA Y SUS HISTORIAS DE SUPERACIÓN
# Procesando artículo: CHIESI ESPAÑA HA RECIBIDO EL SÍ ESTE ENERO DE 2023 A LA INCLUSIÓN DE LAMZEDE® EN LA PRESTACIÓN FARMACÉUTICA DEL SISTEMA NACIONAL DE SALUD...
# Procesando artículo: JAZZ PHARMACEUTICALS RECIBE LA AUTORIZACIÓN DE REEMBOLSO DE EPIDYOLEX® (CANNABIDIOL ALTAMENTE PURIFICADO) PARA EL TRATAMIENTO DE LAS CONVULSIONES ASOCIADAS AL COMPLEJO ESCLEROSIS TUBEROSA EN...
# Procesando artículo: EL ANÁLISIS DE ASOCIACIÓN GENÉTICA DE 77.539 GENOMAS REVELA ETIOLOGÍAS DE ENFERMEDADES RARAS: LA IMPORTANCIA DE UNA ESTRUCTURA UNIFICADA Y CENTRALIZADA
# Procesando artículo: REVISIONES PARA MEJORAR: CÓMO EUROPA DEBERÍA IMPULSAR EL DESARROLLO DE MEDICAMENTOS PARA ENFERMEDADES RARAS
# Procesando artículo: EL GOBIERNO DE CANADÁ MEJORA EL ACCESO A MEDICAMENTOS ASEQUIBLES Y EFECTIVOS PARA ENFERMEDADES RARAS
# Procesando artículo: ESTIMACIÓN DE LOS COSTES SOCIOECONÓMICOS DE LAS ENFERMEDADES RARAS EN HONG KONG: UN AVANCE EN LA LUCHA POR LA COBERTURA UNIVERSAL DE LA SALUD
# Procesando artículo: MEDICAMENTOS HUÉRFANOS CON FINANCIACIÓN APROBADA POR EL CIPMPS DESDE SEPTIEMBRE HASTA DICIEMBRE 2022
# Procesando artículo: MEDICAMENTOS HUÉRFANOS E INDICACIONES APROBADAS POR LA EMA DESDE SEPTIEMBRE HASTA DICIEMBRE 2022
# Procesando artículo: JAZZ PHARMACEUTICALS APUESTA POR LA INNOVACIÓN PARA AYUDAR A LOS PACIENTES CON LMA QUE MÁS LO NECESITAN
# Procesando artículo: LA NUEVA ALIANZA EUROPEA QUE BUSCA ACELERAR LA  INVESTIGACIÓN DE ENFERMEDADES RARAS
# Procesando artículo: HACIA UN NUEVO MARCO POLÍTICO EUROPEO: CONSTRUYENDO JUNTOS EL FUTURO DE LAS ENFERMEDADES RARAS
# Procesando artículo: EL PAQUETE LEGISLATIVO DE FIN DE AÑO BENEFICIARÁ A MILLONES DE AMERICANOS QUE PADECEN UNA ENFERMEDAD RARA
# Procesando artículo: Autoadministración: El paso clave para el bienestar de los pacientes con déficit de Alfa-1 antitripsina (DAAT)
# Procesando artículo: El Sistema Nacional de Salud de España autoriza ravulizumab para el tratamiento de la Hemoglobinuria Paroxística Nocturna (HPN) y el Síndrome Hemolítico Urémico atípico...
# Procesando artículo: Informe “Connecting the Dots”
# Procesando artículo: a Evaluación de Tecnologías Sanitarias (ETS) y el papel de los pacientes en la nueva legislación
# Procesando artículo: Carolina Darias comparte los grandes avances en el abordaje de las enfermedades raras con Latinoamérica
# Procesando artículo: Un nuevo libro blanco describe los problemas relacionados con los retrasos en el diagnóstico de enfermedades pulmonares intersticiales
# Procesando artículo: OTRA INFORMACIÓN DE INTERÉS – SHUa
# Procesando artículo: OTRA INFORMACIÓN DE INTERÉS – JORNADAS
# Procesando artículo: ABORDAJE MULTIDISCIPLINAR DEL SHUa – JORNADA SOBRE ABORDAJE MULTIDISCIPLINAR DE LOS PACIENTES CON MICROANGIOPATÍAS TROMBÓTICAS (MAT)
# Procesando artículo: MEDICAMENTOS HUÉRFANOS E INDICACIONES APROBADAS POR LA EMA DESDE ENERO HASTA ABRIL 2022
# Procesando artículo: SE PUBLICA LA SEGUNDA EDICIÓN DEL MANUAL DE ENFERMEDADES MINORITARIAS EN EL ADULTO
# Procesando artículo: LAS ENFERMEDADES RARAS Y EL DEPORTE ADAPTADO. UN EJEMPLO PARA LA IGUALDAD DE OPORTUNIDADES Y LA MEJORA DE LA CALIDAD DE VIDA
# Procesando artículo: LA ASOCIACIÓN ESPAÑOLA DE LABORATORIOS DE MEDICAMENTOS HUÉRFANOS Y ULTRAHUÉRFANOS (AELMHU) PRESENTÓ SU INFORME ANUAL DE ACCESO DE LOS MEDICAMENTOS HUÉRFANOS EN ESPAÑA
# Procesando artículo: EL ANÁLISIS FACIAL PARA LA MEJORA DEL DIAGNÓSTICO DE EERR: UN PROYECTO DE COLABORACIÓN INTERNACIONAL
# Procesando artículo: INTERNACIONAL- SEGÚN UN ESTUDIO, LA CARGA ECONÓMICA DE LAS ENFERMEDADES RARAS ES 10 VECES MAYOR QUE LA DE ENFERMEDADES PREVALENTES
# Procesando artículo: MEDICAMENTOS HUÉRFANOS CON FINANCIACIÓN APROBADA POR EL CIPMPS DESDE SEPTIEMBRE HASTA DICIEMBRE 2021
# Procesando artículo: MEDICAMENTOS HUÉRFANOS E INDICACIONES APROBADAS POR LA EMA DESDE SEPTIEMBRE HASTA DICIEMBRE 2021
# Procesando artículo: ESPAÑA – INTELIGENCIA ARTIFICIAL PARA MONITORIZAR LA DISTROFIA MUSCULAR DE DUCHENNE
# Procesando artículo: ESPAÑA – DARIAS AVANZA LA PRÓXIMA EVALUACIÓN DE LA ESTRATEGIA ESTATAL DE ENFERMEDADES RARAS DEL SISTEMA NACIONAL DE SALUD
# Procesando artículo: EUROPA – PREMIO EURORDIS DE FOTOGRAFÍA
# Procesando artículo: EUROPA – EL PROGRAMA CONJUNTO EUROPEO SOBRE ENFERMEDADES RARAS PUBLICA SU CONVOCATORIA PARA 2022
# Procesando artículo: EUROPA – EL PARLAMENTO EUROPEO PIDE UN NUEVO PLAN DE ACCIÓN EUROPEO SOBRE ENFERMEDADES RARAS PARA 2023
# Procesando artículo: INTERNACIONAL – LA ONU APRUEBA LA PRIMERA RESOLUCIÓN SOBRE LAS PERSONAS QUE VIVEN CON ENFERMEDADES RARAS (EERR) Y SUS FAMILIAS
# Procesando artículo: MEDICAMENTOS HUÉRFANOS aprobados por la Agencia Europea del Medicamentos (EMA) entre enero y abril de 2021
# Procesando artículo: Internacional – Red Internacional de Enfermedades Raras: Declaración sobre la recuperación del Covid-19
# Procesando artículo: Europa – Se presenta el Informe Anual «Indicadores de acceso a terapias innovadoras en Europa (W.A.I.T Indicator 2020)»
# Procesando artículo: Consulta pública previa proyecto de Real Decreto (RD) sobre tratamientos especiales: una oportunidad para potenciar el acceso a los MMHH en España
# Procesando artículo: Desayuno sobre acceso a diagnóstico y tratamiento en Enfermedades Raras
# Procesando artículo: Feder lanza la campaña: «Síntomas de esperanza» contra la vulnerabilidad de las enfermedades raras
# Procesando artículo: Celebrado el tercer diálogo newsRARE «Evaluación Económica aplicada en onco-hematología: ¿elementos diferenciales en LMA?»
# Procesando artículo: Medicamentos Huérfanos con financiación aprobada por la Comisión Interministerial de precios de los medicamentos (CIPM) entre enero y abril de 2021
# Procesando artículo: Burosumab llega a España para el tratamiento de los pacientes con Hipofosfatemia ligada al cromosoma X (XLH)
# Procesando artículo: Celebrado el segundo diálogo newsRARE «Análisis de decisión multi-criterio aplicado en Medicamentos huérfanos: avances y aplicaciones en Leucemia Mieloide Aguda»
# Procesando artículo: MEDICAMENTOS HUÉRFANOS CON FINANCIACIÓN APROBADA POR LA COMISIÓN INTERMINISTERIAL DE PRECIOS DE LOS MEDICAMENTOS (CIPM) ENTRE OCTUBRE Y DICIEMBRE DE 2020
# Procesando artículo: MEDICAMENTOS HUÉRFANOS APROBADOS POR LA AGENCIA EUROPEA DEL MEDICAMENTO (EMA) ENTRE OCTUBRE Y DICIEMBRE DE 2020
# Procesando artículo: SOBI PRESENTA EL DOCUMENTO DE REFLEXIONES: LA HUMANIZACIÓN EN LAS ENFERMEDADES RARAS
# Procesando artículo: CELEBRADO EL I CONGRESO INTERNACIONAL SOBRE LOS EFECTOS DE LA COVID-19 EN LAS PERSONAS CON ENFERMEDADES POCO FRECUENTES
# Procesando artículo: EL PROGRAMA AcogER, REFERENTE INTERNACIONAL PARA LA ATENCIÓN DE LA INFANCIA CON ENFERMEDADES RARAS EN EL SISTEMA DE PROTECCIÓN
# Procesando artículo: EL PROGRAMA CONJUNTO EUROPEO DE ENFERMEDADES RARAS PRESENTA NUEVOS OBJETIVOS
# Procesando artículo: SE CREA LA PRIMERA BASE DE DATOS CON VARIABLES GENÉTICAS DE LA POBLACIÓN ESPAÑOLA
# Procesando artículo: LA NUEVA ACADEMIA CIBERER PARA PACIENTES OFRECERÁ FORMACIÓN SOBRE LA INVESTIGACIÓN EN ENFERMEDADES RARAS
# Procesando artículo: EXPERTOS Y PACIENTES PLANTEAN MÁS DE 30 PROPUESTAS AL MINISTERIO DE SANIDAD PARA DEFINIR EL FUTURO DE LAS ENFERMEDADES RARAS
# Procesando artículo: MEDICAMENTOS HUÉRFANOS CON FINANCIACIÓN APROBADA POR LA COMISIÓN INTERMINISTERIAL DE PRECIOS DE LOS MEDICAMENTOS (CIPM) ENTRE JUNIO Y SEPTIEMBRE DE 2020
# Procesando artículo: MEDICAMENTOS HUÉRFANOS APROBADOS POR LA AGENCIA EUROPEA DEL MEDICAMENTO (EMA) ENTRE JUNIO Y SEPTIEMBRE DE 2020
# Procesando artículo: XIII CONGRESO INTERNACIONAL DE ENFERMEDADES RARAS
# Procesando artículo: UN TERCIO DE LAS ASOCIACIONES DE ENFERMEDADES RARAS SE BENEFICIAN DE LOS TALLERES REALIZADOS POR FEDER DURANTE LA PANDEMIA
# Procesando artículo: MÁS DE 2.500 PERSONAS CON ENFERMEDADES RARAS, BENEFICIARIAS DEL FONDO FEDER DE EMERGENCIA FRENTE A COVID-19
# Procesando artículo: LANZAMIENTO DE LA CAMPAÑA “SONIDOS QUE QUITAN LA RESPIRACIÓN” PARA CONCIENCIAR SOBRE LA FIBROSIS PULMONAR IDIOPÁTICA
# Procesando artículo: SHARE4RARE CREA UN REGISTRO INTERNACIONAL PARA CONOCER CÓMO AFECTA LA COVID-19 A LOS PACIENTES CON ENFERMEDADES RARAS Y SUS FAMILIARES
# Procesando artículo: UN INFORME EVALÚA LA NORMATIVA EUROPEA DE MEDICAMENTOS HUÉRFANOS
# Procesando artículo: MEDICAMENTOS HUÉRFANOS CON FINANCIACIÓN APROBADA POR LA COMISIÓN INTERMINISTERIAL DE PRECIOS DE LOS MEDICAMENTOS (CIPM) EN 2020
# Procesando artículo: EL INSTITUTO DE SALUD CARLOS III LIDERA UN PROYECTO SOBRE DETERMINANTES DEL RETRASO DIAGNÓSTICO EN PERSONAS CON ENFERMEDADES RARAS
# Procesando artículo: ACUERDO POR EL QUE SE DECLARA A LOS MEDICAMENTOS HUÉRFANOS EXONERADOS DE INCORPORARSE AL SISTEMA DE PRECIOS DE REFERENCIA
# Procesando artículo: LA SEFH IDENTIFICA LOS NUEVOS MEDICAMENTOS HUÉRFANOS NO ONCOLÓGICOS EN EVALUACIÓN POR LA EMA
# Procesando artículo: PUBLICACIÓN DE LA RARE CANCER AGENDA 2030
# Procesando artículo: UN SISTEMA “A PRUEBA DE FUTURO Y DE CRISIS”: LAS CLAVES DE LA FUTURA ESTRATEGIA FARMACÉUTICA DE LA UE
# Procesando artículo: LISTADO DE MEDICAMENTOS PARA ENFERMEDADES RARAS EN EUROPA
# Procesando artículo: WAYLIVRA® (VOLANESORSÉN) PARA EL TRATAMIENTO DEL SÍNDROME DE QUILOMICRONEMIA FAMILIAR
# Procesando artículo: PALYNZIQ® PARA TRATAR LA FENILCETONURIA
# Procesando artículo: ZYNTEGLO® PARA EL TRATAMIENTO DE BETATALASEMIA
# Procesando artículo: ULTOMIRIS® (RAVULIZUMAB), PARA EL TRATAMIENTO DE PACIENTES ADULTOS CON HEMOGLOBINURIA PAROXÍSTICA NOCTURNA
# Procesando artículo: XOSPATA® (GILTERITINIB) PARA EL TRATAMIENTO DE PACIENTES ADULTOS CON LEUCEMIA MIELOIDE AGUDA RECURRENTEO REFRACTARIA CON UNA MUTACIÓN FLT3
# Procesando artículo: OLGA DELGADO, NUEVA PRESIDENTA DE LA SOCIEDAD ESPAÑOLA DE FARMACIA HOSPITALARIA
# Procesando artículo: EL GOBIERNO APRUEBA 2,8 MILLONES DE EUROS PARA LAS ENFERMEDADES RARAS Y NEURODEGENERATIVAS
# Procesando artículo: LISTADO DE ENFERMEDADES RARAS Y SUS SINÓNIMOS
# Procesando artículo: AELMHU PRESENTA LOS DATOS DE ACCESO A LOS MEDICAMENTOS HUÉRFANOS EN ESPAÑA
# Procesando artículo: LA SEFH DESARROLLA UNA METODOLOGÍA DE EVALUACIÓN QUE INTEGRA LA VISIÓN DE LOS PACIENTES
# Procesando artículo: APLICACIÓN MÓVIL DE ORPHANET
# Procesando artículo: SERVICIO DE INFORMACIÓN Y ORIENTACIÓN SOBRE ENFERMEDADES RARAS DE FEDER
# Procesando artículo: GLIBENCLAMIDA (AMGLIDIA®) PARA EL TRATAMIENTO DE LAS DIABETES MELLITUS NEO-NATAL
# Procesando artículo: SNS @GESFARMA
# Procesando artículo: REGLAMENTO INTERNO DE LA COMISIÓN INTERMINISTERIAL DE PRECIO DE LOS MEDICAMENTOS (CIMP)
# Procesando artículo: CIMA 2.0
# Procesando artículo: La Comunidad de Madrid habilita un espacio web informativo sobre Enfermedades Raras
# Procesando artículo: RESULTADOS DEL PROYECTO INNOVCARE
# Procesando artículo: INFORME GENERAL SOBRE ‘EL ESTADO DE LA CUESTIÓN’ SOBRE LAS ACTIVIDADES EN ENFERMEDADES RARAS EN EUROPA
# Procesando artículo: INFORME SOBRE MEDICAMENTOS HUÉRFANOS APROBADOS POR LA COMISIÓN EUROPEA ENTRE 2012 Y 2016. ANÁLISIS DE LA SITUACIÓN DE PRECIO Y REEMBOLSO EN ESPAÑA.
# Procesando artículo: INOTERSEN (TEGSEDI®) PARA EL TRATAMIENTO DE LA AMYLIODOSIS TRANSTIRETINA HEREDITARIA (HATTR)
# Procesando artículo: CICLOSPORINA (VERKAZIA®) PARA EL TRATAMIENTO DE LA QUERATO- CONJUNTIVITIS VERNAL GRAVE (VKC) EN NIÑOS Y ADOLESCENTES
# Procesando artículo: RUCAPARIB (RUBRACA®) PARA EL TRATAMIENTO DEL CÁNCER DE OVARIO, TROMPAS DE FALOPIO Y PERITONEO, CON MUTACIONES (BRCA)
# Procesando artículo: GEMTUZUMAB OZOGAMICINA (MYLOTARG®) PARA EL TRATAMIENTO DE LA LEUCEMIA MIELOIDE AGUDA (LMA)
# Procesando artículo: Centro de Revisiones y Difusión del Servicio Nacional de Salud británico, CRD NHS (Universidad de York
# Procesando artículo: CUESTIONES EN PRECIO Y FINANCIACIÓN DE MEDICAMENTOS
# Procesando artículo: AGENCIA ESPAÑOLA DE MEDICAMENTOS Y PRODUCTOS SANITARIOS (AEMPS)
# Procesando artículo: DRUG PRICING LAB
# Procesando artículo: Poster científico sobre Centro de Referencia de Enfermedades Raras en España: Análisis de Situación y Propuestas de Futuro
# Procesando artículo: Guía de Recomendaciones para el Abordaje de las Enfermedades Raras
# Procesando artículo: El CGCOF publica el monográfico “Punto Farmacológico 112”
# Procesando artículo: España trabajará en redes europeas ERNs de 17 grupos de patologías
# Procesando artículo: El SNS cuenta ya con 90 medicamentos huérfanos incorporados en su cartera básica
# Procesando artículo: Plan de Modernización de los Medicamentos Huérfanos de la FDA
# Procesando artículo: Los pacientes logran la participación real en el SNS
# Procesando artículo: Guía de Ayuda en el Desarrollo de Medicamentos Huérfanos para Investigadores
# Procesando artículo: Metformina, designada medicamento huérfano para el tratamiento de la enfermedad de Lafora
# Procesando artículo: Clormetina (Ledaga®) para el tratamiento de la micosis fungoide
# Procesando artículo: Selexipag (Uptravi®) para el tratamiento a largo plazo de la Hipertensión Arterial Pulmonar (HAP)
# Procesando artículo: Inotuzumab ozogamicin (Besponsa®) para el tratamiento de Leucemia Linfoblástica Aguda (LLA) de precursores de linfocitos B en adultos
# Procesando artículo: GESTIONA RADIO
# Procesando artículo: Registro de Pacientes: PAtient REgistries iNiTiative (PARENT)
# Procesando artículo: Red Española de Registros de Enfermedades Raras
# Procesando artículo: Red Europea de Líneas de Ayuda en Enfermedades Raras | Servicio de Información y Orientación de FEDER
# Procesando artículo: Libro sobre “Ética en la Investigación de las Enfermedades Raras”
# Procesando artículo: Monografía sobre “Criterios de Financiación y Reembolso de los Medicamentos Huérfanos”
# Procesando artículo: Guía para la Valoración de la Discapacidad en Enfermedades Raras
# Procesando artículo: Sanidad de Castilla y León acortará los plazos de diagnóstico de enfermedades raras
# Procesando artículo: La EMA y la FDA refuerzan la colaboración en el compromiso del paciente
# Procesando artículo: Se crea la Asociación de Enfermedades Raras de La Rioja
# Procesando artículo: Informe sobre Registros de Enfermedades Raras en Europa
# Procesando artículo: Ataluren (Translarna®) para niños ambulatorios con Distrofia Muscular de Duchenne (DMD)
# Procesando artículo: Selexipag (Uptravi®) para el tratamiento de la Hipertensión Arterial Pulmonar
# Procesando artículo: Temsirolimus, designado medicamento huérfano para el tratamiento de la adrenoleucodistrofia
# Procesando artículo: Mapa Asistencial para Enfermedades Raras de la Comunidad de Madrid
# Procesando artículo: Estrategia en Enfermedades Raras del Sistema Nacional de Salud
# Procesando artículo: Proyecto Europeo sobre Enfermedades Raras
# Procesando artículo: INSTITUTO DE MEDICINA GENÓMICA
# Procesando artículo: Recomendaciones metodológicas para el desarrollo de guías de práctica clínica en EE.RR
# Procesando artículo: Guía Metodológica de Evaluación Económica aplicada a Medicamentos Huérfanos
# Procesando artículo: Se crea el Registro Estatal de Enfermedades Raras
# Procesando artículo: Holoclar® para el tratamiento de enfermedades de la córnea
# Procesando artículo: Eculizumab (Soliris®) para el tratamiento de Hemoglobinuria Paroxística Nocturna (HPN)
# Procesando artículo: Se aprueban dos nuevos tratamientos para dos enfermedades ultra-raras metabólicas
# Archivo noticias_actualidad.json actualizado.
# Procesando artículo: HUMANIZACIÓN Y ATENCIÓN CENTRADA EN LA PERSONA: EL COMPROMISO DE LA COMUNIDAD DE MADRID CON LAS ENFERMEDADES RARAS
# Procesando artículo: EU HTA Joint Clinical Assessment: are patients with rare disease going to lose out?
# Procesando artículo: OPTIMIZACIÓN DE LA PARTICIPACIÓN DE LOS PACIENTES EN LA EVALUACIÓN DE LOS MEDICAMENTOS
# Procesando artículo: Carlos Dévora, Néboa Zozaya, Patricia Rizzi – Nuevos marcos para la evaluación de tecnologías sanitarias y sus posibles efectos en los medicamentos huérfanos.
# Procesando artículo: José Martínez Olmos – Patient mobility and healthcare decentralization: responses and challenges in the Spanish National Healthcare System
# Procesando artículo: Gloria Marquina Ospina – Management of patients with rare adult solid cancers: objectives and evaluation of European Reference Networks (ERN) EURACAN
# Procesando artículo: Organización institucional en la atención a las enfermedades raras
# Procesando artículo: Alberto Jiménez Morales – 2017-2023: State Of The Art Of Gene Therapies In Rare Diseases In Europe: The Dynamics Of Clinical R&D, New Approved...
# Procesando artículo: Innovación terapéutica en las enfermedades raras
# Procesando artículo: José Manuel  Martínez Sesmero – Towards Better  Pharmaceutical  Provision in EuropeWho Decides the  Future?
# Procesando artículo: ROBERTO SALDAÑA NAVARRO – The role of stakeholder involvement in the evolving EU HTA process: Insights generated through the European Access Academy’s multi-stakeholder preconvention...
# Procesando artículo: Desentrañando el presente: Un recorrido por las políticas y normativas de enfermedades raras desde 2021
# Procesando artículo: Navegando en el laberinto de las enfermedades raras: desafíos y recomendaciones para la detección precoz y el cribado neonatal
# Procesando artículo: GLORIA GONZÁLEZ ASEGUINOLAZA – NEWBORN SCREENING BY GENOMIC SEQUENCING: OPPORTUNITIES AND CHALLENGES
# Procesando artículo: ITZIAR ASTIGARRAGA AGUIRRE – NEEDS AND OPPORTUNITIES IN 20 COUNTRIES PARTICIPATING IN THE UNDIAGNOSED DISEASES NETWORK INTERNATIONAL
# Procesando artículo: Value-based healthcare en el ámbito de las EERR
# Procesando artículo: ALBERTO NÚÑEZ ELVIRA – Towards value- based healthcare for inherited metabolic disorders: An overview of current practices for persons with liver glycogen storage disease...
# Procesando artículo: JORGE MESTRE-FERRANDIZ – Assessing the value of orphan drugs using conventional cost- efectiveness analysis: Is it fit for purpose?
# Procesando artículo: Antoni Montserrat Moliner  – The added value of a European Reference Network on rare and complex connective tissue and musculoskeletal diseases: insights after...
# Procesando artículo: SOLEDAD CABEZÓN RUIZ – Making Sure That Orphan Incentives Tip the Right Way in Europe
# Procesando artículo: Elementos de optimización en EERR:  fondos europeos
# Procesando artículo: Modelos innovadores de financiación  en el campo de las EERR: DE DÓNDE VENIMOS Y HACIA DÓNDE VAMOS
# Procesando artículo: Félix Rubial Bernárdez – DISPONIBILIDAD, ACCESIBILIDAD, ASEQUIBILIDAD
# Procesando artículo: ANTONI GILABERT PERRAMON – Implementing Risk-Sharing Arrangements for Innovative Medicines: The Experience in Catalonia (Spain)
# Procesando artículo: JOSÉ LUIS SEGU TOLSA – IMPLEMENTING OUTCOMES-BASED MANAGED ENTRY AGREEMENTS (OBMEA) FOR RARE DISEASE TREATMENTS: NUSINERSEN AND TISAGENLECLEUCEL
# Procesando artículo: RENATA VILLORO VALDÉS – Collaborative model for diagnosis and treatment of very rare diseases: experience in Spain with thymidine kinase 2 deficiency
# Procesando artículo: INDALECIO CORUGEDO DE LAS CUEVAS – Clinical development innovation in rare diseases: lessons learned and best practices from the DevelopAKUre consortium
# Procesando artículo: La atención a los pacientes con enfermedades raras y el acceso a los medicamentos huérfanos después de la pandemia COVID-19
# Procesando artículo: JORDI GOL-MONTSERRAT – The use of machine learning in rare diseases: a scoping review
# Procesando artículo: FÉLIX RUBIAL BERNÁRDEZ – TELEMEDICINE DURING THE COVID-19 PANDEMIC: IMPACT ON CARE FOR RARE CANCERS
# Procesando artículo: MIGUEL ÁNGEL CALLEJA HERNÁNDEZ – Outcomes-based reimbursement for genetherapies in practice: the experience of recently launched CAR-T cell therapies in major European countries
# Procesando artículo: MIGUEL ÁNGEL CASADO – New Models for the Evaluation of Specialized Medicinal Products: Beyond Conventional Health Technology Assessment and Pricing
# Procesando artículo: SANTIAGO DE LA RIVA – Shaping the future of rare diseases after a global health emergency: Organisational points to consider
# Procesando artículo: MARILÓ EDO SOLSONA Y JOSÉ LUIS POVEDA ANDRÉS – Time for change? The why, what and how of promoting innovation to tackle rare diseases...
# Procesando artículo: JUAN OLIVA MORENO – Social/economic costs and health-related quality of life in patients with spinal muscular atrophy (SMA) in Spain y The Economic Impact...
# Procesando artículo: CARME PINYOL i VILLENA – Patient-Reported Outcome and Observer- Reported Outcome. Assessment in Rare Disease Clinical Trials: An ISPOR COA. Emerging Good Practices Task...
# Procesando artículo: IMMA GRAU CORRAL – Patient reported outcome measures in rare diseases: a narrative review
# Procesando artículo: Renata Villoro – Patient empowerment of people living with rare diseases. Its contribution to sustainable and resilient healthcare systems
# Procesando artículo: Lilisbeth Perestelo-Pérez – Shared decision making in rare diseases: an overview
# Procesando artículo: Antoni Montserrat Moliner – LA RECOMENDACIÓN DE EURORDIS: CÓMO PROTEGER A LOS PACIENTES CON ENFERMEDADES RARAS DURANTE LA PANDEMIA DE COVID-19
# Procesando artículo: Juan E. del Llano Señarís – The SARS, MERS and novel coronavirus (COVID-19) epidemics, the newest and big- gest global health threats: what lessons...
# Procesando artículo: Javier Mar Medina – UN EXPERIMENTO DE ELECCIÓN DISCRETA PARA EXTRAER PREFERENCIAS SOCIALES SOBRE ENFERMEDADES RARAS
# Procesando artículo: Jaime Espín Balbino – UNA REVISIÓN SISTEMÁTICA DE MODELOS MCDA DE EVALUACIÓN DE MEDICAMENTOS HUÉRFANOS
# Procesando artículo: Antoni Gilabert Perramon – IMPLEMENTACIÓN DE UN MCDA REFLEXIVO PARA MEDICAMENTOS HUERFANOS EN EL SENO DEL CATSALUT
# Procesando artículo: Renata Villoro Valdés – Estudio comparativo de los precios de Medicamentos Huérfanos en Europa
# Procesando artículo: Ma Reyes Abad Sazatornil – El acceso de los pacientes a medicamentos para enfermedades raras en países europeos
# Procesando artículo: Jorge Mestre-Ferrandiz – Disponibilidad y Acceso a Medicamentos Huérfanos. ¿Qué sabemos?
# Procesando artículo: Vicente Merino Bohórquez y Miguel Ángel Calleja Hernández – Destellos de luz en la caja negra de los precios de los medicamentos huérfanos
# Procesando artículo: Juan Oliva – DECISIONES DE FINANCIACIÓN BASADAS EN EL VALOR DE LOS MM.HH: REVISIÓN DE SITUACIÓN Y MARCO DE DECISIÓN
# Procesando artículo: D. Santiago Pérez-Camarero – LA PRIMERA DÉCADA DE LEGISLACIÓN SOBRE MEDICAMENTOS HUÉRFANOS EN LA UE
# Procesando artículo: Alba Ancochea – Los pacientes: protagonistas del camino hacia la innovación en ER
# Procesando artículo: ANTONI MONTSERRAT – Políticas sobre MM.HH: un caso interesante para analizar
# Procesando artículo: Álvaro Hidalgo – Diversidad y heterogeneidad de la denominación y definición de las enfermedades raras y los medicamentos huérfanos en función de dónde y...
# Procesando artículo: Renata Villoro – La importancia de las enfermedades raras desde el punto de vista médico y social
# Procesando artículo: Roberto Marín Gil – Fármacos efectivos en enfermedades raras: una oferta que no podremos rechazar
# Archivo noticias_articulos.json actualizado.
# Procesando artículo: El impacto del nuevo marco de evaluación de tecnologías sanitarias  sobre los medicamentos dirigidos a EERR
# Procesando artículo: La organizacion de los recursos asistenciales en la atencion de las personas con enfermedades raras
# Procesando artículo: Innovación terapéutica en el ámbito de las EERR
# Procesando artículo: Pulso de la situación
# Procesando artículo: Políticas y proceso regulatorio en EERR
# Procesando artículo: Detección precoz y cribado neonatal en EERR
# Procesando artículo: Iniciativas sanitarias basadas en el valor en el ámbito de las EERR
# Procesando artículo: Los fondos europeos como elementos de optimización en EERR
# Procesando artículo: Modelos innovadores de financiación en  el campo de las EERR
# Procesando artículo: Casos de éxito en pacientes con enfermedades raras y su entorno
# Procesando artículo: La aplicación de la inteligencia artificial a las enfermedades raras
# Procesando artículo: Elementos esenciales para el acceso al mercado en enfermedades raras
# Procesando artículo: Políticas para el desarrollo de tratamientos dirigidos a enfermedades raras
# Procesando artículo: Opinión de los agentes del sistema sobre el uso de PROM y PREM en enfermedades raras
# Procesando artículo: El empoderamiento de los pacientes con enfermedades raras y su incorporación en la toma de decisiones
# Procesando artículo: Los efectos del COVID-19 en los pacientes con enfermedades raras en España
# Archivo noticias_barometro.json actualizado.
# Procesando artículo: UN PASO HACIA LA NORMALIZACIÓN: EL IMPACTO DE LAS NUEVAS TERAPIAS EN EL ANGIOEDEMA HEREDITARIO
# Procesando artículo: LA VOZ DE LOS PACIENTES: HACIA UNA NUEVA ERA EN EL ACCESO A MEDICAMENTOS HUÉRFANOS
# Procesando artículo: Pablo Méndez Valera – CSL Behring y el Futuro de la Terapia Génica en Hemofilia B: Innovación y Acceso
# Procesando artículo: Girisha Fernando, Josep MarÍa Guiu, David Duro – Gestión de Acuerdos Farmacéuticos Transformada: El Servicio Revolucionario de Lyfegen
# Procesando artículo: Marta Carrera – Desafíos y soluciones: Boehringer Ingelheim en la vanguardia de las iniciativas en el ámbito de las enfermedades raras
# Procesando artículo: Inés Perea del Pino – Revolucionando la salud: Innovaciones en tratamientos para enfermedades desafiantes
# Procesando artículo: Ricardo Ogawa – Innovación y acceso: Estrategias de una compañía farmacéutica ante los retos del sector en España
# Procesando artículo: Ana Infante González de la Aleja – Avances en el tratamiento del síndrome de Dravet y el síndrome de Lennox-Gastaut: Mejorando la vida de...
# Procesando artículo: ISABEL PINEROS ANDRÉS – LA IMPORTANCIA DEL DIÁLOGO TEMPRANO Y LA PLANIFICACIÓN ENTRE LA COMPAÑÍA FARMACÉUTICA Y LA ADMINISTRACIÓN
# Procesando artículo: JOSÉ LUIS SÁNCHEZ CHORRO – EL VALOR DESDE EL PUNTO DE VISTA DEL PACIENTE
# Procesando artículo: ROSANA CAJAL MERINO – Nuevos proyectos en los que se sumerge Jazz Pharmaceuticals para mejorar la calidad de vida del paciente
# Procesando artículo: SERGI BELTRÁN AGULLÓ – Secuenciación genómica para acortar el tiempo de diagnóstico en las EERR: los Proyectos más relevantes del Centro Nacional de Análisis...
# Procesando artículo: Antonio Charrua – La importancia del trabajo en equipo para una detección precoz y mejora en la asistencia de los pacientes con EERR en...
# Procesando artículo: Jonathan Galduf – MEDICAMENTOS HEMODERIVADOS:  RETOS Y SOLUCIONES
# Procesando artículo: Pau Ricós Muñoz – RETOS EN EL ACCESO REAL A LAS INNOVACIONES TERAPÉUTICAS: ACUERDOS DE RIESGO COMPARTIDO Y PAGO POR RESULTADOS
# Procesando artículo: Juan Carlos Saorín Lozano – Una reflexión Estratégica sobre la financiación y el acceso a las terapias dirigidas a EERR
# Procesando artículo: Raquel Contreras – UCB: inspirados por los pacientes e impulsados por la ciencia
# Procesando artículo: Inés Perea – Telemedicina y salud digital: el punto de vista de la industria
# Procesando artículo: Juan Lobera – Presente y futuro de la salud digital en enfermedades raras
# Procesando artículo: Pablo Talavera – Investigación, telemedicina y salud digital en enfermedades raras
# Procesando artículo: Federico Plaza – Investigación, telemedicina y salud digital en enfermedades raras
# Procesando artículo: Isabel Pineros – La colaboración entre administraciones sanitarias y la industria farmacéutica es esencial para el acceso de los pacientes a las terapias avanzadas
# Procesando artículo: Nuria Saval Sargas – Colaboración Público-Privada para la mejora en el abordaje de las enfermedades raras
# Procesando artículo: Iván Silva Romero – La Estrategia Europea y los nuevos incentivos para la promoción de los medicamentos huérfanos
# Archivo noticias_colaboracion-publico-privada.json actualizado.
# Procesando artículo: V EDICIÓN DEL CURSO DE VERANO newsRARE 2024 EXPLORANDO EL FUTURO DE LAS ENFERMEDADES RARAS: TERAPIAS INNOVADORAS, COLABORACIÓN INSTITUCIONAL Y VALOR SOCIAL
# Procesando artículo: V EDICIÓN DEL CURSO DE VERANO 2024
# Procesando artículo: Cristóbal Belda Iniesta – CURSO DE VERANO 2023
# Procesando artículo: Belén Pérez González – CURSO DE VERANO 2023
# Procesando artículo: NUEVAS ESTRATEGIAS Y TENDENCIAS EN EL MANEJO DE LAS  ENFERMEDADES RARAS
# Procesando artículo: Raquel Yahyaoui Macías – CURSO DE VERANO 2023
# Procesando artículo: Francisco Javier Vázquez Granado – CURSO DE VERANO 2023
# Procesando artículo: ÁLVARO HIDALGO – CURSO DE VERANO 2023
# Procesando artículo: JUAN CARLOS VALENZUELA – CURSO DE VERANO 2022
# Procesando artículo: MARIÁN CORRAL LÓPEZ – CURSO DE VERANO 2022
# Procesando artículo: JOSÉ MARTÍNEZ OLMOS – CURSO DE VERANO 2022
# Procesando artículo: SOLEDAD CABEZÓN – CURSO DE VERANO 2022
# Procesando artículo: JAVIER GARCÍA CASTRO – CURSO DE VERANO 2022
# Procesando artículo: AVANCES EN EL ABORDAJE DE LAS ENFERMEDADES RARAS: LOGROS Y DESAFÍOS PARA LOS SISTEMAS NACIONALES DE SALUD
# Archivo noticias_cursos.json actualizado.
# Procesando artículo: CELEBRADO EL PRIMER DIÁLOGO NEWSRARE “ESCALAS DE VALOR EN ONCO-HEMATOLOGÍA: ANÁLISIS MEDIANTE EL EJEMPLO DE LA LEUCEMIA MIELOIDE AGUDA”
# Archivo noticias_dialogos.json actualizado.

# %% [markdown]
# Cargar todos los artículos en un df común (Update all_articles_with_source.csv)

# %%
import os
import json
import pandas as pd

# Folder containing your JSON files
json_folder = "/content/drive/MyDrive/AN_NO_STRUCT/TFM/articles"

# List to store extracted articles
articles_list = []

# Loop through each JSON file
for filename in os.listdir(json_folder):
    if filename.endswith(".json"):
        with open(os.path.join(json_folder, filename), "r", encoding="utf-8") as f:
            data = json.load(f)
            # Extract articles and store their source file
            for article in data:
                articles_list.append({
                    "article_url": article.get("url", ""),  # Store original JSON filename
                    "title": article.get("title", ""),
                    "content": article.get("content", "")
                })

# Convert to Pandas DataFrame
df = pd.DataFrame(articles_list)

# Add combined text column for topic modeling
df["text"] = df["title"] + " " + df["content"]

# Drop empty texts
df = df[df["text"].str.strip() != ""]

# Display first few rows
df.head()

# Save DataFrame to CSV
df.to_csv("/content/drive/MyDrive/AN_NO_STRUCT/TFM/all_articles_with_source.csv", index=False, encoding="utf-8")

# %%
df=pd.read_csv("/content/drive/MyDrive/AN_NO_STRUCT/TFM/all_articles_with_source.csv")
df.head()
